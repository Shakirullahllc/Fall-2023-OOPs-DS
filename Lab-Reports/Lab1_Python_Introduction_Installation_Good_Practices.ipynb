# %% [markdown]
# # University of Engineering and Technology Peshawar, Jalozai Campus
#
# <h2 style="font-family: 'Arial', sans-serif; text-align: center; color: #2980b9; font-size: 36px; font-weight: bold; text-transform: uppercase; letter-spacing: 2px;">
#     Lab 1: Python Introduction, Installation, and Good Practices
# </h2>
#
# <p style="font-family: 'Georgia', serif; text-align: center; color: #34495e; font-size: 20px; margin-bottom: 20px;">
#     <b>Lab Title:</b> <span style="color: #e74c3c;">EE-271 “OOP & Data Structures Lab”</span><br>
#     <b>Date:</b> <span style="color: #e74c3c;">Thursday, January 9, 2024</span><br>
#     <b>Time:</b> <span style="color: #e74c3c;">3 Hours</span>
# </p>
#
# <hr style="border-top: 3px solid #2980b9;">
#
# <h2 style="font-family: 'Arial Black', Gadget, sans-serif; text-align: center; background: linear-gradient(to right, #3498db, #8e44ad); color: white; padding: 15px; border-radius: 10px; font-size: 28px;">
#     🎓 EE-271 OOP & Data Structures Lab Report
# </h2>
#
# <hr style="border-top: 3px solid #3498db;">
#
# <div style="font-family: 'Georgia', serif; color: #2c3e50; font-size: 18px;">
#     <p style="font-weight: bold; color: #2980b9;">📋 Lab Information</p>
#     <ul style="font-family: 'Verdana', sans-serif; font-size: 16px; color: #34495e; line-height: 1.8;">
#         <li><b style="color: #e74c3c;">Lab No.:</b> <span style="font-weight: bold; color: #2980b9;">1</span></li>
#         <li><b style="color: #e74c3c;">Lab Title:</b> <span style="font-weight: bold; color: #2980b9;">Python Introduction, Installation, and Good Practices</span></li>
#         <li><b style="color: #e74c3c;">Lab Date:</b> <span style="font-weight: bold; color: #2980b9;">January 9, 2025</span></li>
#     </ul>
# </div>
#
# <hr style="border-top: 3px solid #27ae60;">
#
# <div style="font-family: 'Georgia', serif; color: #2c3e50; font-size: 18px;">
#     <p style="font-weight: bold; color: #2980b9;">🙋‍♂️ Submitted By</p>
#     <ul style="font-family: 'Verdana', sans-serif; font-size: 16px; color: #34495e; line-height: 1.8;">
#         <li><b style="color: #e74c3c;">Name:</b> <span style="font-weight: bold; color: #2980b9;">Shakir Ullah</span></li>
#         <li><b style="color: #e74c3c;">Roll No.:</b> <span style="font-weight: bold; color: #2980b9;">23JZELE0524</span></li>
#         <li><b style="color: #e74c3c;">Section:</b> <span style="font-weight: bold; color: #2980b9;">A</span></li>
#     </ul>
# </div>
#
# <hr style="border-top: 3px solid #f39c12;">
#
# ## 1. Install IDE
# ### Recommended IDEs for Python Development
# - **[Anaconda](https://www.anaconda.com/download)**
#   A powerful Python data science platform with integrated IDE and tools.
# - **[Python](https://www.python.org/downloads/)**
#   Download and install the official Python distribution.
#
# ---
#
# ## 2. Create a GitHub Account
# - Visit **[GitHub](https://github.com/)** to create an account for hosting repositories and sharing code.
#
# ---
#
# ## 3. Helpful Resources for Code Development
# Explore these platforms to enhance your Python programming skills:
#
# 1. **[Stack Overflow](https://stackoverflow.com/)**
#    - Get answers for programming-related questions.
#    - Learn from solutions to common issues.
#
# 2. **[Real Python](https://realpython.com/)**
#    - Detailed tutorials and in-depth Python articles.
#    - Visit the **[YouTube Channel](https://www.youtube.com/@realpython)** for tutorials.
#
# 3. **[Geeks for Geeks](https://www.geeksforgeeks.org/)**
#    - A great resource for beginner to advanced programming tutorials.
#
# 4. **[W3Schools](https://www.w3schools.com/)**
#    - Beginner-friendly coding tutorials with examples.
#
# ---
#
# ## 4. Jupyter Notebook
# Learn how to work with Jupyter Notebooks for Python development.
# [Watch this tutorial](https://www.youtube.com/watch?v=HW29067qVWk&t=27s) to get started.
#
# ---
#
# ## 5. Virtual Environments
# Managing Python environments is crucial for project isolation.
# [Learn to set up a virtual environment](https://www.youtube.com/watch?v=23aQdrS58e0&t=10s).
#
# ---
#
# ## 6. Online Code Editors
# If you prefer online development, you can use **[Google Colab](https://colab.google/)** for running Python code directly from the browser.
#
# ---
#
# ## 7. Recommended Courses
# **[Python for Everybody Specialization](https://www.coursera.org/specializations/python)**
# - A beginner-friendly course that covers Python fundamentals.
#
# For more free courses, you can explore the **[YouTube Link](https://www.youtube.com/watch?v=UjeNA_JtXME&list=PLlRFEj9H3Oj7Bp8-DfGpfAfDBiblRfl5p)**.
#
# ---
#
# ## 8. GitHub Repository for Example Codes
# Explore this [GitHub repository](https://github.com/SyedHasnat/OOP-in-Python-UET/tree/main) for practical Python OOP examples and sample codes.
#
# ---
#
# ## 9. Recommended Books
# 1. *Python Tricks: The Book* by Dan Bader
# 2. *How to Think Like a Computer Scientist* by Allen Downey
